# %%
data1 = [{"type": "named_anchor", "value": {"heading": "NHS provider directory", "anchor_id": "nhs-provider-directory"}}, {"type": "document_link", "title": "NHS provider directory"}, {"type": "named_anchor", "value": {"heading": "Registers of licensed healthcare providers", "anchor_id": "registers-of-licensed-healthcare-providers"}}, {"type": "document", "value": {"title": "Public_Registry_FT_directory_190403", "document": 26415, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "independent-provider-public-register-171120", "document": 26416, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "PublicRegister_NHS_controlled_providers_240619", "document": 26417, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "named_anchor", "value": {"heading": "Regulatory action", "anchor_id": "regulatory-action"}}, {"type": "document_link", "title": "Licensed independent healthcare providers"}, {"type": "free_text", "title": ""}]

data2 = [{"type": "document", "value": {"title": "261120-board-agenda", "document": 26428, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "261120-item-1-minutes-board-meeting-011020", "document": 26429, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "261120-item-3-operational-performance-update", "document": 26430, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "261120-item-3-financial-position-month-6", "document": 26431, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "261120-item-3-wave-2-and-winter-public-board-report", "document": 26432, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "261120-item-4-innovation-research-and-life-sciences-and-aac", "document": 26433, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "261120-item-5-next-steps-integrated-care-systems", "document": 26434, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "261120-item-5-integrating-care-next-steps-for-integrated-care-systems", "document": 26435, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "261120-item-6-staff-health-and-wellbeing-offer", "document": 26436, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "261120-item-7-use-of-nhs-england-seal", "document": 26437, "type": "pdf", "num_pages": "2", "file_size": "1000"}}]

data3 = [{"type": "document", "value": {"title": "Easy Read - LeDeR death data - Nov 20 2020 P1.0", "document": 26443, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Nov 20 2020 P1.0", "document": 26444, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy Read - LeDeR death data - Nov 13 2020 P1.0", "document": 26445, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Nov 13 2020 P1.0", "document": 26446, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy Read - LeDeR death data - Nov 06 2020 p1.0", "document": 26447, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Nov 06 2020 p1.0", "document": 26448, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy Read - LeDeR death data - Oct 30 2020 p1.0", "document": 26449, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Oct 30 2020 p1.0", "document": 26450, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "easy-read-leder-death-data-oct-23-2020", "document": 26451, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "plain-english-leder-death-data-oct-23-2020", "document": 26452, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy Read - LeDeR death data - Oct 16 2020 p1.0", "document": 26453, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Oct 16 2020 p1.0", "document": 26454, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy_Read_LeDeR_death_data_Oct_09_2020_v0.2", "document": 26455, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain_English_LeDeR_death data_Oct_09_2020_p1.0", "document": 26456, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "easy-read-LeDeR-death-data-oct-02-2020", "document": 26457, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "plain-english-LeDeR-death-data-oct-02-2020", "document": 26458, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "easy-read-LeDeR-death-data-sep-25-2020", "document": 26459, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "plain-english-LeDeR-death-data-sep-25-2020", "document": 26460, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy Read - LeDeR death data - Sep 18 2020 p1.0 (1)", "document": 26461, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Sep 18 2020 p1.0", "document": 26462, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "easy-read-LeDeR-death-data-sep-11-2020", "document": 26463, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "plain-english-LeDeR-death-data-sep-11-2020", "document": 26464, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy Read - LeDeR death data - Sep 04 2020 p1.0", "document": 26465, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Sep 04 2020 p1.0", "document": 26466, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy Read - LeDeR death data - Aug 28 2020", "document": 26467, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Aug 28 2020", "document": 26468, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy Read - LeDeR death data - Aug 21 2020", "document": 26469, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Aug 21 2020", "document": 26470, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Easy Read - LeDeR death data - Aug 14 2020", "document": 26471, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "Plain English - LeDeR death data - Aug 14 2020", "document": 26472, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-covid-19-weekly-deaths-07.08.2020", "document": 26473, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR COVID-19 weekly deaths 31.07.2020", "document": 26474, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR COVID-19 weekly deaths 24.07.2020", "document": 26475, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR COVID-19 weekly deaths 17.07.2020", "document": 26476, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-COVID-19-weekly-deaths-100720", "document": 26477, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-covid-19-weekly-deaths-03072020", "document": 26478, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-covid-19-weekly-deaths-26062020", "document": 26479, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-covid-19-weekly-deaths-19.06.2020", "document": 26480, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-covid-19-weekly-deaths-12062020", "document": 26481, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-covid-19-weekly-deaths-05062020", "document": 26482, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-covid-19-29.05.2020", "document": 26483, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-COVID-19-weekly-deaths-22-05-2020", "document": 26484, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-COVID-19-weekly-deaths-15-05-2020", "document": 26485, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-COVID-19-daily-deaths-v1", "document": 26486, "type": "pdf", "num_pages": "2", "file_size": "1000"}}, {"type": "document", "value": {"title": "LeDeR-COVID-19-weekly-deaths-v1", "document": 26487, "type": "pdf", "num_pages": "2", "file_size": "1000"}}]

# %%
from itertools import groupby
from operator import itemgetter

data = data1
mapped_type_postitions = []

docs = []

""" ['anchor', 'doc', 'anchor', 'doc', 'doc', 'doc', 'anchor', 'doc', 'doc'] """

for i in range(0, len(data)):
    if data[i]['type'] == 'named_anchor':
        mapped_type_postitions.append('anchor')
        
    elif data[i]['type'] != 'named_anchor':
        mapped_type_postitions.append('doc')
        

    last_item = mapped_type_postitions[-1]

    if last_item != 'anchor':
        # append to docs and remove last
        del mapped_type_postitions[-1]
        
        docs.append('doc')

    elif last_item == 'anchor' and len(docs):
        del mapped_type_postitions[-1]
        mapped_type_postitions.append(docs)
        mapped_type_postitions.append('anchor')
        docs = []

    if i == len(data) - 1:
        mapped_type_postitions.append(docs)
        docs = []

    # print(i, len(mapped_type_postitions), final_length)
    # elif i == len(mapped_type_postitions) -1:
    #     mapped_type_postitions.append(docs)
    # if last_item == 'anchor':
    #     del mapped_type_postitions[-1]
    #     mapped_type_postitions.append('anchor')
    #     mapped_type_postitions.append(docs)
        
    # else:
    #     mapped_type_postitions.append(docs)
    #     mapped_type_postitions.append('anchor')
    #     docs = []
print(docs)
print(mapped_type_postitions)
# Out:
# []
# ['anchor', ['doc'], 'anchor', ['doc', 'doc', 'doc'], 'anchor', ['doc', 'doc']]

# %%
import json
new_stream = []

block_group = {
    'type': 'document_group',
    'value': []
}
# print(data)
if not 'anchor' in mapped_type:
    # just group all docs into one group
    for item in data:
        block_group['value'].append(item)
    new_stream.append(block_group)
    print(json.dumps(new_stream, indent=4))
    block_group['value'] = []
else:
    # split docs into groups and add titles to match anchors
    counter = 0
    """ ['anchor', 'doc', 'anchor', 'doc', 'doc', 'doc', 'anchor', 'doc', 'free_text', 'end'] """

    mapped_type_grouped = []

    for i in range(0, len(mapped_type) - 1): # avoid looping end marker
        doc_group = []
        if mapped_type[i] == 'anchor':
            mapped_type_grouped.append('anchor')
        elif mapped_type[i] == 'doc':
            doc_group.append(['doc'])
    print(mapped_type_grouped)    
        # if mapped_type[i] == 'doc':
        #     block_group['value'].append(data[i])
        #     if mapped_type[i-1] == 'anchor':
        #         new_stream.append(data[i-1])
        #     elif mapped_type[i+1] == 'anchor':
        #         new_stream.append(block_group)
        #         block_group['value'] = []
        #         new_stream.append(data[i])

        # if mapped_type[i] == 'anchor' and mapped_type[i+1] == 'doc':
        #     new_stream.append(item)

        # if mapped_type[i] == 'doc' and mapped_type[i+1] == 'doc':
        #     block_group['value'].append(item)

        # if mapped_type[i] == 'doc' and mapped_type[i+1] == 'anchor':
        #     block_group['value'].append(item)
        #     new_stream.append(block_group)
        #     block_group['value'] = []
            
        # elif mapped_type[i] == 'doc' and mapped_type[i+1] != 'doc':
        #     block_group['value'].append(item)

        # if mapped_type[i] == 'doc' and not item['type'] == 'free_text':
        #     block_group['value'].append(item)
        #     print(block_group['value'])

        # elif mapped_type[i] == 'anchor' and len(block_group['value']) > 0:
        #     new_stream.append(block_group)
        #     new_stream.append(item)

        # elif mapped_type[i] == 'anchor' and len(block_group['value']) == 0:
        #     new_stream.append(item)
        #     block_group['value'].clear()

        # else:
        #     new_stream.append(item)

        # print(block_group)
        # elif mapped_type[i] == 'anchor':
        #     if len(block_group['value']):
        #         new_stream.append(block_group)
        #         block_group['value'] = []
        #         new_stream.append(item)
        #     else:
        #         print(item)
        #         new_stream.append(item)

    print(json.dumps(new_stream, indent=4))
# Out:
# ['anchor', 'anchor', 'anchor']
# []
